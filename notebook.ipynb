# %% [markdown]
# # Bienvenue dans Jupyter Notebook
# Ce notebook a été créé pour tester l'installation.

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

from functions import *
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio

# Charger le fichier .mat
data = sio.loadmat("data/mnist_train_test.mat")

print(f" The keys of the matrix are:  {data.keys()}")

# Extraire train et test
train = data["train"]       #<class 'numpy.ndarray'>
test = data["test"]         #<class 'numpy.ndarray'>

d, m = X_train.shape
print(d)

check_gradient(train)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#  The keys of the matrix are:  dict_keys(['__header__', '__version__', '__globals__', 'd', 'test', 'train'])
# 785
# min distance to {−1,0} = 0.0005959280204788087
# min distance to {−1,0} = 0.0005959282637109098
# min distance to {−1,0} = 0.0005959283129080006
# min distance to {−1,0} = 0.0005959283720580189
# min distance to {−1,0} = 0.0005959284431682477
# min distance to {−1,0} = 0.0005959285286634142
# min distance to {−1,0} = 0.0005959286314514145
# min distance to {−1,0} = 0.0005959287550298953
# min distance to {−1,0} = 0.0005959289036034932
# min distance to {−1,0} = 0.0005959290822286079
# min distance to {−1,0} = 0.0005959292969839325
# min distance to {−1,0} = 0.0005959295551747346
# min distance to {−1,0} = 0.0005959298655877632
# min distance to {−1,0} = 0.0005959302387905652
# min distance to {−1,0} = 0.0005959306874716574
# min distance to {−1,0} = 0.0005959312269103734
# ...

# %%
theta, res = gradient_descent(train, lam=5e-3, time_budget_sec=180, eps=1e-3)

ks = np.arange(len(res["gnorm"]))
plt.figure(figsize=(6,4))
plt.semilogy(ks, res["gnorm"], marker='o', linewidth=1)
plt.xlabel("itération k"); plt.ylabel("||∇f_λ(θ_k)||")
plt.title("Convergence GD, pas = 1/L"); plt.grid(True, which="both")
plt.show()
